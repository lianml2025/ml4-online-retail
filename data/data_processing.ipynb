# %%
from retail_cleaning_pipeline import clean_retail_data

# Clean the data
clean_df = clean_retail_data("raw.xlsx")

# Save to CSV and Excel
clean_df.to_excel("cleaned_retail.xlsx", index=False)

print("✅ Data exported successfully.")
# Out:
# INFO:root:Loading data...
# INFO:root:Adding date columns...
# INFO:root:Handling missing CustomerID...
# INFO:root:Removing invalid InvoiceNo entries...
# INFO:root:Adding Subtotal column...
# INFO:root:Flagging cancellations...
# INFO:root:Removing invalid quantity records...
# INFO:root:Cleaning complete.
# ✅ Data exported successfully.
